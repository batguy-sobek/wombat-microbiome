# %%
## this is to see how similar in composition the 4 outliers in the data are.

# %%
## lets run some aplpha diversity metrics to see if certain features are skewing the data.

# %%
qiime diversity alpha \
--i-table /hpcfs/users/a1805545/16s_reads/qiime_output/NHNW-SHNW-final-table-noSC-ANCOM-ms8-mf-500.qza \
--p-metric observed_features \
--o-alpha-diversity /hpcfs/users/a1805545/16s_reads/qiime_output/alpha-diversity/NHNW-SHNW-alpha-obs-feat.qza

# %%
qiime diversity alpha \
--i-table /hpcfs/users/a1805545/16s_reads/qiime_output/NHNW-SHNW-final-table-noSC-ANCOM-ms8-mf-500.qza \
--p-metric dominance \
--o-alpha-diversity /hpcfs/users/a1805545/16s_reads/qiime_output/alpha-diversity/NHNW-SHNW-alpha-dominance.qza

# %%
qiime diversity alpha \
--i-table /hpcfs/users/a1805545/16s_reads/qiime_output/NHNW-SHNW-final-table-noSC-ANCOM-ms8-mf-500.qza \
--p-metric singles \
--o-alpha-diversity /hpcfs/users/a1805545/16s_reads/qiime_output/alpha-diversity/NHNW-SHNW-alpha-singles.qza

# %%
## now lets convert these files so we can visulaise them

# %%
qiime diversity alpha-group-significance \
--i-alpha-diversity /hpcfs/users/a1805545/16s_reads/qiime_output/alpha-diversity/NHNW-SHNW-alpha-obs-feat.qza \
--m-metadata-file /hpcfs/users/a1805545/16s_reads/metadata.txt \
--o-visualization /hpcfs/users/a1805545/16s_reads/qiime_output/alpha-diversity/NHNW-SHNW-alpha-obs-feat.qzv

# %%
qiime diversity alpha-group-significance \
--i-alpha-diversity /hpcfs/users/a1805545/16s_reads/qiime_output/alpha-diversity/NHNW-SHNW-alpha-dominance.qza \
--m-metadata-file /hpcfs/users/a1805545/16s_reads/metadata.txt \
--o-visualization /hpcfs/users/a1805545/16s_reads/qiime_output/alpha-diversity/NHNW-SHNW-alpha-dominance.qzv

# %%
qiime diversity alpha-group-significance \
--i-alpha-diversity /hpcfs/users/a1805545/16s_reads/qiime_output/alpha-diversity/NHNW-SHNW-alpha-singles.qza \
--m-metadata-file /hpcfs/users/a1805545/16s_reads/metadata.txt \
--o-visualization /hpcfs/users/a1805545/16s_reads/qiime_output/alpha-diversity/NHNW-SHNW-alpha-singles.qzv

# %%
## lets run ANCOMBC with an edited feature table to see if any taxa are enriched in just the outlier samples vs the others.

# %%
qiime composition ancombc \
--i-table /hpcfs/users/a1805545/16s_reads/qiime_output/NHNW-SHNW-final-table-noSC-ANCOM-ms8-mf-500-lvl6.qza \
--m-metadata-file /hpcfs/users/a1805545/16s_reads/metadata.txt \
--p-formula category \
--p-reference-levels category::ingroup \
--o-differentials /hpcfs/users/a1805545/16s_reads/qiime_output/NHNW-SHNW-ANCOMBC-ms8-mf-500-lvl6-outlier-test.qza

# %%
qiime composition da-barplot \
--i-data /hpcfs/users/a1805545/16s_reads/qiime_output/NHNW-SHNW-ANCOMBC-ms8-mf-500-lvl6-outlier-test.qza \
--p-level-delimiter ';' \
--o-visualization /hpcfs/users/a1805545/16s_reads/qiime_output/NHNW-SHNW-ANCOMBC-ms8-mf-500-lvl6-outlier-test.qzv

# %%
## we will take a look at the shannon diversity of the outliers

# %%
qiime diversity alpha-group-significance \
--i-alpha-diversity /hpcfs/users/a1805545/16s_reads/qiime_output/NHNW-SHNW-wild-core-div/shannon_vector.qza \
--m-metadata-file /hpcfs/users/a1805545/16s_reads/metadata.txt \
--o-visualization /hpcfs/users/a1805545/16s_reads/qiime_output/NHNW-SHNW-wild-core-div/shannon_vector.qzv

# %%
## make the barplot with updated metadata to see them more easily

# %%
qiime taxa barplot \
--i-table /hpcfs/users/a1805545/16s_reads/qiime_output/NHNW-SHNW-final-table-noSC-ANCOM-ms8-mf-500.qza \
--i-taxonomy /hpcfs/users/a1805545/16s_reads/qiime_output/NHNW-SHNW-22-23-SILVA-taxa.qza \
--m-metadata-file /hpcfs/users/a1805545/16s_reads/metadata.txt \
--o-visualization /hpcfs/users/a1805545/16s_reads/qiime_output/NHNW-SHNW-22-23-SILVA-taxa-Barplot-25000-reads-outlier.qzv
